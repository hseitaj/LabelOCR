# %%
import os
import cv2
import pytesseract
import pandas as pd
from tabulate import tabulate
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
import numpy as np

# Set up Tesseract OCR
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Path to the folder containing PNG images
folder_path = "C:/Users/hseit/Desktop/SummerMCREU/images/"
amount = 0
extracted_data = []

# Keywords for feature detection
keywords = {
    "product_title": ["product name", "name", "product"],
    "directions": ["directions", "usage", "how to use"],
    "supplements_or_elements": ["supplements", "elements", "ingredients"],
    "warnings": ["warnings", "cautions", "precautions"]
}

# Iterate over the PNG images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        amount += 1
        print("File found: " + str(amount))
        # Load the label image
        image_path = os.path.join(folder_path, filename)
        image = cv2.imread(image_path)
        print()

        # Preprocess the image
        resized_image = cv2.resize(image, (800, 600))  # Resize the image
        normalized_image = cv2.normalize(resized_image, None, 0, 255, cv2.NORM_MINMAX)  # Normalize pixel values
        denoised_image = cv2.fastNlMeansDenoisingColored(normalized_image, None, 10, 10, 7, 21)  # Denoise the image
        gray = cv2.cvtColor(denoised_image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale

        # Perform text detection
        contours, _ = cv2.findContours(gray.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        text_regions = []
        for contour in contours:
            x, y, w, h = cv2.boundingRect(contour)
            if w > 10 and h > 10:  # Filter out small contours
                text_regions.append((x, y, w, h))

        # Find the contour with maximum area
        max_contour = max(text_regions, key=lambda r: r[2] * r[3])
        x, y, w, h = max_contour

        # Crop the image using the contour coordinates
        cropped_image = gray[y:y+h, x:x+w]

        # Perform text recognition on the cropped image
        extracted_text = pytesseract.image_to_string(cropped_image).strip()

        # Match keywords to determine the feature type
        extracted_dict = {}
        for feature, feature_keywords in keywords.items():
            for keyword in feature_keywords:
                if keyword.lower() in extracted_text.lower():
                    extracted_dict[feature] = extracted_text
                    break

        # Store the extracted data
        data = {
            "image_path": image_path,
            "product_title": extracted_dict.get("product_title", ""),
            "directions": extracted_dict.get("directions", ""),
            "supplements_or_elements": extracted_dict.get("supplements_or_elements", ""),
            "warnings": extracted_dict.get("warnings", "")
        }
        extracted_data.append(data)

        # Display the results
        for region in text_regions:
            x, y, w, h = region
            cv2.rectangle(resized_image, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Print extracted text
        print("Extracted Text:")
        print(extracted_text)

# Create a DataFrame from the extracted data
df = pd.DataFrame(extracted_data)

# Define a function to truncate long strings
def truncate_string(text, max_length=30):
    if len(text) > max_length:
        return text[:max_length] + '...'
    return text

# Apply string truncation to the DataFrame
df = df.applymap(truncate_string)

# Prepare the data for LSTM training
encoder = LabelEncoder()
df_encoded = pd.DataFrame()
for column in df.columns:
    df_encoded[column] = encoder.fit_transform(df[column])

    
sequences = df_encoded.apply(lambda x: list(x), axis=1)
max_length = max(df_encoded.apply(len))
padded_sequences = pad_sequences.reshape(padded_sequences.shape[0], padded_sequences.shape[1])


# Split the data into training and testing sets (60% train, 40% test)
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, df_encoded, test_size=0.3, random_state=42)

# Convert the target labels to numpy arrays
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# Get the number of classes for the output layer
num_classes = len(encoder.classes_)


# Build the LSTM model
vocab_size = len(encoder.classes_)
embedding_dim = 50
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_length))
model.add(LSTM(64))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# Compile and train the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)

# Print the accuracy
print("Accuracy:", accuracy)

# Get the predicted labels for the test set
y_pred = model.predict(X_test)
predicted_labels = encoder.inverse_transform(np.argmax(y_pred, axis=1))

# Create a DataFrame with the predicted labels and true labels
results_df = pd.DataFrame({'Predicted': predicted_labels, 'True': encoder.inverse_transform(y_test)})

# Display the DataFrame
print("\nModel Predictions:")
print(tabulate(results_df, headers='keys', tablefmt='psql'))

print()

# Display the DataFrame in table format
print("\nExtracted Data:")
print(df.to_string(index=False))
# Out:
# File found: 1
#
# Extracted Text:
# essential
# Waitrose®
# british beef ~
# diced steak
#
# 500ge
# File found: 2
#
# Extracted Text:
# ALUMINUM + FREE
#
# O41 Spéce-
#
# HIGH ENDURANCE® ——
# DEODORANT
#
# NETWT.
# 2.402 682)
# File found: 3
#
# Extracted Text:
#
# File found: 4
#
# Extracted Text:
#
# File found: 5
#
# Extracted Text:
# ALUMINUM + FREE
#
# O41 Spéce-
#
# HIGH ENDURANCE® ——
# DEODORANT
#
# NETWT.
# 2.402 682)
# File found: 6
#
# Extracted Text:
# CONTAINS ODOR-FIGHTING “ATOMIC ROBOTS” THAT “SHooT
# LASERS” AT YOUR “STENCH MONSTERS” AND REPLACES.
# THEM WITH FRESH, CLEAN, MASCULINE “SCENT ELVES”
#
# 48 HOUR ODOR PROTECTION.
# DIRECTIONS: Twist up product. Apply to underarms only.
# Use dally for bost results.
# MARHINGS: DO WOT APPLY TO BROKEN SKIN. I RASH OF IRRITATION OEVELOPS
# DSCONTINUE USE. USE ONLY AS DIRECTED.
# KEEP OUT OF REACH OF CHILDREN.
#
# INGREDIENTS: DIPROPYLENE GLYCOL, WATER,
#
# PROPYLENE GLYCOL, SODIUM STEARATE,
#
# POLOKAMINE 1307, FRAGRANCE, PPG-3 MYRISTYL,
#
# SER, TETRASODIUM EDTA, VIOLET 2, GREEN 6
# Questions? +
#
# GAMBLE,
# OH 45202
#
# PEG
# File found: 7
#
# Extracted Text:
# ive Purpose
# Ger ener pe
# Sits Carborte USP 100mg... Antacid
#
# Usesrcleves _- heartburn
# + acid indigestion 2 sour slamach
# = upscl stomach associated with these symptoms
# Warnings
# Ask a doctor or pharmacist before use If you are,
# presontly taking a preseriplion drug. Antaclas may
# interact with certain proserigtion drugs.
# When using this product
# {do nol take mora than 7 tablets in 24 hours
# Zitpreanant do nottake more than 9 tablets in 24 hours
# J donot use the maximum dosage for more than 2 weeks
# except under the advicu and supervision of a doctor
# Keep aut of reach of children.
#
# Directions
# UgeKs and children 12 years of age and over: chow 2-3
# jets as symptoms occur, br ae difected by a doctor
# = dane take for symptoms that persist for more than 2 weeks
# Unless advised by a doctor
#
# information
# Ree etre mental calclim 400mg, sodium 2a
#
# 2 Store below 30°C (86°F)
#
# =Iactive Ingredients adipic acid, com starch, FDRG blue
# Traces Tear Peas ine, {bec yotsw 4 (arirname) ake
# EDC yellow #6 lake, favors, mineral oll, sodium polyphasphat
# ‘sucrose, tale.
#
# ‘Questions?
#
# 1-800-807-7535
# weekdays,
#
# ew tune. OFF ern EES:
#
# Gisrren,.N4.07059 103593xB
#
# 2014 6k
# File found: 8
#
# Extracted Text:
# [00
# TZ FREE
#
# 103662XB
# File found: 9
#
# Extracted Text:
# NATR@EOLE
# Melatonin 10=<
#
# SLEEP
#
# @ Fall Asleep Faster*
#
# @ Stay Asleep Longert
#
# ® 100% Drug-Free ae ee
#
# 90 GUMMIES
# DIETARY SUPPLEMENT See oR
# File found: 10
#
# Extracted Text:
# DIRECTIONS: Take 2 gummies
# 20-30 minutes before bedtime.
#
# Supplement Facts
#
# ‘Total Carbol
#
# Total Sugars.
# ‘includes 39 Added Sugars
#
# GTHER INGREDIENTS: Organic Tapioca
# Syrup, Organic Cane Sugar, Water,
# ‘Contains 2 percent or less of (Citric Acid,
# Coconut Oil, Carnauba Wax, Fruit and
# Vegetable Juice (for color), Natural
# Flavors, Pectin, Sodium Citrate).
# Manufactured for NATROL LLG,
# Chatsworth, CA 91311, USA
# 1-800-2-NATROL (800-262-8765)
# www.natrol.com
#
# Manufactured in a facility that
# processes products containing
# Milk, Eggs, Tree Nuts, Peanuts,
# Wheat, and Soybeans.
#
# ‘STORE IN A COOL, DRY PLACE.
# KEEP OUT OF REACH OF CHILDREN.
#
# ‘These statements have not
#
# been evaluated by the Food "
# and Drug Administration.
#
# ‘This product is not intended
# to diagnose, treat, cure or
# Prevent any disease.
#
# WARNING: This product is not
# intended to treat insomnia. Do not
# take while operating machinery or
# driving a vehicle. Consult a
# physician before using this
# Product if you are taking
# Medication, have any medical
# condition, are pregnant or
# lactating, have an autoimmune
# condition or depressive disorder, or
# are between the ages of 12-17.
# ‘Not for use by children under the
# age of 12
#
# ae
# File found: 11
#
# Extracted Text:
# Cera
#
# DEVELOPED WITH DERMATOLOGISTS
#
# Daily
# Moisturizing
# Lotion
#
# For Normal to Dry Skin
# Moisturizes & helps restore
# the protective skin barrier
#
# With 3 essential ceramides
# & hyaluronic acid
#
# 12 FL OZ (355 mt)
# File found: 12
#
# Extracted Text:
# a =a
#
# CeraVe® Daily Moisturizing Lotion
#
# Developed with dermatologists, Its unique formuta —
# with 3 essential coramides — molsturizes and helpe
# restore the protective skin barrier.
#
# MVE* Detivory Lightwetghe
# (>) Tocnnstony. @® ee.
# @ Hysturonte Act @S> Fragrance Free
#
# Directions: Apply liberally as often as needed, or as.
# directed by @ physician. Avoid direct contact with eyes. If
# Eontact occurs rinse thoraughly with water.
#
# 20215004V01 — INGREDIENTS: AQUA/WATER/EAU. GLYCERIN.
# GAPRYLIC/CAPRIC TRIGLYCERIDE, CETEARVL ALCOHOL:
# CETYL ALCOHOL, POTASSIUM PHOSPHATE, CERAMIDE NP,
# GERAMIDE AP, CERAMIDE EOP, CARBOMEI, DIMETHICONE,
# CETEARETH~20, BEHENTRIMONIUM METHOSULFATE,
# METHYLPARABEN, SODIUM LAUROYE LACTYLATE,
# CHOLESTEROL, DISGDIUM EDTA, DIPOTASSIUM.
# PHOSPHATE, PROPYLPARABEN.
#
# HYDROLYZE HYALURONIC ACID,
# PHYTOSPHINGOSINE. XANTHAN GUM,
# BOLYSORBATE 20, POLYGLYCERYL-3
# DIISOSTEARATE (CODE FLL. D215763/2)
# File found: 13
#
# Extracted Text:
# BAUSCH + LOMB
#
# Eye Relief.
#
# LUBRICANT EYE DROPS.
#
# Fast relief from
#
# dry eyes
# Replenishes tears
# Rejuvenates eyes
# File found: 14
#
# Extracted Text:
# Drug Facts
#
# Active ingredients Purpose
# Glycerin (0.3%). Lubricant
# Propylene glycol (1.0%). Lubricant
#
# Uses
# = temporary relief of burning and irritation.
#
# due to dryness of the eye
# m_prevents further irritation
#
# Warnings
#
# For external use only
#
# Do not use
#
# m if solution changes color or
# becomes cloudy
#
# When using this product
#
# m™ do not touch tip of container to any surface
# to avoid contamination
#
# m= remove contact lenses before using
#
# mm _replace cap after use
#
# Stop use and ask a dootor if
# You experience eye pain, changes in vision
# Continued redness or irritation of the eye
#
# = condition worsens or persists for more than
# 72 hours
#
# Keep out of reach of children. If swallowed,
#
# get medical help or contact a Poison Control
#
# Genter right away.
#
# Directions
# instill 1 or 2 drops in the affected
# eye(s) as nooded
# File found: 15
#
# Extracted Text:
# ee Qe Syprvss D 2s,
#
# CRAISINS «
#
# DRIED
#
# CRAN-
# BERRIES
#
# NO ARTIFICIAL FLAVORS OR PRESERVATIVES
#
# R 44
# SWEETENED DRIED GRANBERRIES
# (FOZ (1.36 ko)
# File found: 16
#
# Extracted Text:
# Nutrition Facts
# ut 26 servings per
#
# packa
#
# P Wonderful
# Bei sn ust Ei so ISTACHIGS
# Lee ne
#
# With just 2 pinch of sit can
# Serving of Lightly Salted Wao.
# Pistachios is a low-sac7t!
# perfectly seasoned, tas, ¢™-
# The delicious rosstea
# comes through in every pice
# you crack open. Lightly sa
# Wonderful Pistachios ora
# Perfect snacking salt-ematce
#
# WonderfulPistachios.com
#
# you:
#
# evidence sug.
# but does not prove
# HEART ating 1.5 ounces =
# HEALTHY Of most nuts, such >
# pistachios, as part of 2 diet low in
# saturated fet and cholesterol may
# reduce the risk of heart disease See
#
# m for fat contes
#
# PROTEIN, the accompanyir
# trade dress are trademarks
# Pistachios & Almonds LUC
#
# Tyuch a nutrient
# dally diet 2.000
#
# nunrtion advice:
#
# UStachios, sea salt
#
# 50
# aenderful Pistachios, Light Salted conta
#
# Site Roasted & Sa
# P93249 Product of USA. Ze cussts
# File found: 17
#
# Extracted Text:
# Wonderful
#
# PISTACHIOS
#
# With just a pinch of salt, each
# Serving of Lightly Salted Wonderful
# Pistachios is a low-sodium,
# perfectly seasoned, tasty snack.
# Phe delicious roasted flavor
# comes through in every pistachio
# you crack open. Lightly Salted
# Wonderful Pistachios are your
# perfect snacking salt-ernative.
#
# WonderfulPistachios.com
#
# Scientific evidence suggests
# but does not prove that
# ewes eating 1.5 ounces per day
# HEALTHY Of most nuts, such as
# pistachios, as part of a diet low in
# saturated fat and cholesterol may
# reduce the risk of heart disease. See
# nutrition information for fat content.
#
# © 2021 Wonderful Pistachios & Almonds (LC
# All Rights Reserved. WONDERFUL. PLANT
# PROTEIN, the accompanying logos and
# trade dress are trademarks of Wonde'l
# Pistachios & Almonds LLC or Its affiliates
#
# Sa nutrition Gluten:
# sea salt.
#
# ee ree
# tS Pistachios,
#
# -
# Braet eres 50% less sodium than oupRaase gant
# ios, Lightly Sat ans ‘Ot SOE
# MO3046 Boa tachios, — Lightly Salted contains 65mM@.oi j= 13%
#
# i
# xe gated out
# File found: 18
#
# Extracted Text:
# ings per container
# Serving size 1 pack (50g) (4 biscuits)
# ees
#
# Galories
# File found: 19
#
# Extracted Text:
#
# File found: 20
#
# Extracted Text:
# NDC 11822-3155-4
#
# first aid antiseptic /
# oral debriding agent
#
# HYDROGEN
# PEROXIDE
#
# FL OZ
#
# 32
# (1 QT) 946 mL
# File found: 21
#
# Extracted Text:
# Drug Facts SAFETY SEAL UNBEN CAP 5 BROKEN O
#
# Active ingredient Purpose
# Hydrogen peroxide 3%.......First ald antiseptic/oral dobriding agent
#
# Uses _m first aid to help prevent the risk of Infection In minor
# Cuts, scrapes, and burns!
#
# 'm aids in the removal of phlegm, mucus, or other secrotions
# associated with occasional sore mouth
#
# Warnings
# For external use only.
# Do not use mm in the eyes or apply over large areas of tho body
# mi longer than one week
# [Ask a doctor before use if you have
# deep puncture wounds, animal bites or serious bus
# Stop use and ask @ doctor ifm swelling, rash, or fevor develops
# 1m the condition persists or gets worse
# sore mouth symptoms do nat improve in 7 days
# inritation, pain, or redness persists or worsen
# Keep out of reach of children. irawallowed, qet medical Ralp oF
# contact Poison Control Center (1-800-222-1222) right away.
#
# Directions For use asa first ald antiseptic:
# Clean affected area. ‘mit bandaged, lt dry first
# ‘apply smail amount of product on atiocted arca 1-3 times a day
# i may be covered with a'sterllo bandage
# For uso as an oral debriding agent (oral rinse)
# ‘mi adults and children 2 years of age and overs
# ‘mbc with an equal amount of water
# Swish around in the mouth over affected area for at least 1
# minute and then spit out, Do not swallow
# ‘use Up fo 4 times dally after meals and ai bedtime or as
# Girectad by a dentist or doctor
# ‘= children under 12 years Should be supervised in the use of this
# Product
# = children under 2 years of age: consult a doctor or dentist
# Other Information wm keop tighty closed and in
# lark place at room temperate
# $5.00 not shake bottle, Hold away from tace when opening. | =
#
# Jnactive ingredient purtied water
#
# Questions or comments?
# {CaN4-877-753-909 Monday friday 9AM-5PM EST
#
# BISTRIBOTED By: RITE AID, 30 HUNTER LANE
# CAMP HILT PA AZOLL wunuctosberars -
# Rope rosa GUARANTEE:
# File found: 22
# Extracted Text:
# KILLS 99.9% OF GERMS
# THAT CAUSE BAD BREATH,
# PLAQUE & GINGIVITIS . a
#
# ANTISEPTIC
#
# LISTERINE
# COOL MINT
#
# FOR A FRESHER &
# CLEANER MOUTH THAN
# BRUSHING ALONE
#
# a seocereg
#
# \
#
# NLT P27 Hay
# ee — a
#
# .
# File found: 23
#
# Extracted Text:
# WEN. Kills Germs by Mi ns on Conta
# guna eR NE ERINE® ‘Antiseptic twice daily to help:
# se COOL MINTS O'Gingivitis MiFreshen Breath i K
#
# Prevent &
# Germs Between Teeti
#
# Reduce Plaque
#
# Purposes
#
# ees Antiplaque/antigingivitis,
# = plague + gingivitis,
#
# Donatuae cloren under 12 years of age
#
# THIS FORMULA
# IS NOT SOLD TO
#
# ‘ae delist smmptome perast, new symptoms appear, or conditions worsen after regular uso
#
# ‘ers aval reac of children. f more than used for rinsing is accidentally swallowed, get medical help
# ‘cata Patson COM GENT VN AWAY.
#
# Directions
#
# venga nae
#
# ANY RETAILER AS
# ‘donot swallow
#
# A STORE BRAND.
# = feu reg 5 acon wi 20 mL GS RT Tee OF4 TRSPOON
#
# Oi ifomation ie jeter qpare Pasting. Moeeva ang TOP
# Se eng OS RN Se aan as we aaa
# <iveing
#
# i emesionts
#
# Tosser
#
# Favor Greon
#
# edients water. Alcohol (21.636), Sorbitol, Poloxamer 407, Benzolc Acid, Sodium
# 2? alto -ree 888-222-0182 or 215-278 8765 (colegd,
# Tatas aroun
#
# —
#
# = Helps prevent and
# Feduce piantie
#
# = Helps prevent an
# feduce gingivitis
#
# aah es
#
# SOSSUE enstonn com
# ‘anes CO
# File found: 24
#
# Extracted Text:
# INGREDIENTS: DISTILED WATER
# CALORIES MSR UTED BY: Walmart Inc, Bentonville, AR ZT
# PERBOTHE PROCESSED BY STEAMDISTRLATION: NOI STERKE: ASDRETDBY
# Sey LABELING DIRECTIONS FORUSEOF NENT TCRSIT,
# UALTY INFORMATION
#
# PA NUTRITIONAL SOURCE, OR BOTTLED WATER
# FO -BTT-24- 8392 OR GOTO wow premiunwaers Ssh
# ‘Youve this Pret’ antes you (FoF
# toby arent complete hi ratousand we
# replcet ot refund You
# Your opinion m
# to talk, call us at
# File found: 25
#
# Extracted Text:
# GIORGIO ARMANI
#
# ABSOLU
#
# TaATCreT mld Va
# File found: 26
#
# Extracted Text:
# SUPPORT &
# RECOVERY
#
# y 4
# Z
# FOR MUSCLE
#
# senvnes
#
# 73:
# 7 KG)
#
# =) LB 2
# SRQIEINPOWDER DRINK Mix, NET WT 5
# File found: 27
#
# Extracted Text:
# Sewing size 31g (About 1 Scoop)
#
# ‘Amount per serving
#
# You Work out, o
# balanced, high-proteir
#
# GOLD STANDARD 100%
# mixability and superior drin
# — __ ee eee
#
# Check out OPTIMUMNUTRITION.COM
# rae agae es training tips.
#
# nlend (Whey Protein
# Peston Concenat! af
#
# Dalai earn tere
# fu Sahat Focepherats, nen taken 2
# OMAN MAND soy,
#
# eo ay
#
# CRTIMCM NUTRITION. He
# ay Roe, Sule
#
# Diners Groves 6051
#
# EPVTEN rR
#
# BYWENTS sory
#
# Vo VEIGHT og =
#
# A
# anuracrunen 7H
#
# ONTLLIS
# 231v
# File found: 28
#
# Extracted Text:
# SH 0
#
# 31GRAMS# 6 6-8FLOZ — 30 sEconns
# ee “, oa seente
#
# Power BEVERAGE
#
# For best results, mix up your shake 30-80 minutes
# you work out, or have it as an anytime snack in your
# balanced, high-protein diet
#
# GOLD STANDARD 100% WHEY" is designed for maximum
# mixability anc! superfar drinkability,
#
# Check out OPTIMUMNUTRITION.COM for recipes and
# training tips,
#
# Sungesteg
# ety oon
# Beale sp
#
# sear habithy sults, consume ancush potsin1a net ri"
# [rauietaente with combination of high pate uke 2
# doplomantstnreuighaue the Gay es part ws paloncee et
#
# “Naturally Occurring Amino Acids
#
# S7OREIN A COOL Ry PLACE
#
# Nay Gtrrze to 7H eo7™
# Sine sasNG
# File found: 29
#
# Extracted Text:
# Cera
#
# Daily
# Moisturizing
# Lotion
#
# For Normal to Dry Skin
#
# Moisturizes & helps restore
# the protective skin barrier
#
# With 3 essential ceramides
# & hyaluronic acid
#
# 12 FL OZ (355 ml)
# File found: 30
#
# Extracted Text:
# CeraVe® Daily Moisturizing Lotion
#
# veloped with dermatologists, Its unique formula —
# iuith S essential ceramides — molaturizes and helps
#
# restore the protective skin barrier.
#
# Lightweight &
#
# pyer netivery ;
# Feenneloy nn SE cine
# Ores PEARS
#
# Gentle on skin Allergy tested | Non-comedegenic
#
# Directions: Apply liberally as often as needed, or as
# directed by a physician. Avoid direct contact with eyes. If
# contact occurs rinse thoroughly with water.
#
# EOP. CARBOME!
# CETEARETH-20, BEHENTRIMONIUM METHOSULPATE,
# METHYLPARABEN, SODIUM LAUROYL LACTYLATE.
# CHOLESTEROL, DISODIUM EDTA, DIPOTASSIUAL
# PHOSPHATE, PROPYLPARABEN,
# HYDROLYZED HYALURONIC ACID,
# PHYTOSPHINGOSINE, XANTHAN OUM,
# BOLYSORBATE 20, POLYGLYGERYL-
# DIISOSTEARATE (CODE Fl.L. D215763/2)
# File found: 31
#
# Extracted Text:
# yf vavue size
# Cera
#
# Hydrating
# Facial
# Cleanser
#
# For Normal to Dry Skin
#
# Cleanses, hydrates & helps
# restore the protective skin barrier
#
# With 3 essential ceramides
# & hyaluronic acid
#
# 16 FL OZ (473 mU
# File found: 32
#
# Extracted Text:
# CeraVe® Hydrating Facial Cleanser
#
# Developed with dermatologists, its unique formula —
# with 3 essential ceramides — cleanses, hydrates and
# helps restore the protective skin barrier.
#
# MVE® Delivery
#
# Technology Non-Comedogenic
# Controlled release Won't clog pores
#
# for all day hydration
#
# Hyaluronic Acid Fragrance Free
# Helps retain skin's To avoid fragrance
# natural moisture irritation
#
# Non-drying
#
# Paraben fr
#
# Gentle on skin
#
# Directions: Wet skin with lukewarm water. Massage
# cleanser into skin in a gentle, circular motion. Rinse. Avoid
# direct eye contact with eyes. if contact occurs, rinse
# thoroughly with water.
#
# 2021506 4 ~ INGREDIENTS: AQUA/WATER/EAU, GLYCERIN, CETEARYL
# ALCOHOL, PEG-40 STFARATE, STEARYL ALCOHOL, POTASSIUM PHOSPHATE,
# CERAMIDE NP, CERAMIDE AP, CERAMIDE EOP, CARBOMER, GLYGERYL
# STEARATE. BEHENTRIMONIUM METHOSULFATE, SODIUM LAUROYL,
# LACTYLATE, SODIUM HYALURONATE,
#
# CHOLESTEROL, PHENOXYETHANOL, DISODIUM ad
# EDIA, DIPOIASSIUM PHOSPHATE, =
# TOCOPHEROL, PHYTOSPHINGOSINE, XANTHAN =
# GUM. CETYL ALCOHOL, POLYSORBATE 20, na
# ETHYLHEXYLGLYCERIN (CODE F.l.L.10214533/3) a
#
# >
#
# =
# Ceravew Lic, iS
# New York, NY 10001 =
# MVE fas regiaterad teadomark iS
# ehbra Technology, Lis —
#
# Imported ingrediente 1” mm
#
# Se12672028060
#
# MYUSBL
# File found: 33
#
# Extracted Text:
# ped with dermatologists, its unique formuta —
# ial ceramides — exfoliates to remove dirt
# ftening and smoothing skin.
#
# Develo}
# with 3 essent
# & oil while so
#
# Free of _ Salicylic Acia
# Mechanicat Exfoliates and
# Exfoliant softens to smooth
# Gently smooths skin rough skin
#
# Fragrance Free
# To avoid fragrance
# irritation
#
# Vitamin D
# Helps provide
# antioxidant benefits
#
# Directions: Wet skin with lukewarm water. Massage cleanser
# inte skin in a gentle, circular motion. Rinse. Avoid contact
# with eyes. If contact occurs rinse thoroughly with water
#
# 20215025V01 - INGREDIENTS: AQUA/WATCR/EAU, COCAMIDOPROPYL
# HYDROXYSULTAINE, GLYCERIN, SODIUM LAUROYL SARCOSINATE,
# NIACINAMIDE, GLUCONOLACTONE, PFG-150 PENTAFRYTHRITYL
# TETRASTEARATE, SODIUM METHYL COCOYL TAURATE, ZEA MAYS:
# OIL/CORN OIL, CERAMIDE NP. CERAMIDE AP, CERAMIDE EOP, CARBOMFR
# CALCIUM GLUCONATE, SODIUM CHLORIDE. SALICYLIC
#
# ACID. SODIUM BENZOATE, SODIUM LAUROYL LACTYLATE,
# CllOlFCALCIFEROL, CHOl FSTEROL, PHENOXYETHANOL
# DISODIUM FOTA, TETRASODIUM EDTA, HYDROLYZED
# HYALURONIC ACID, PHYTOSPHINGOSINE. XANTHAN GUM
# FTHYLHEXYLGLYCERIN (CODE FIL 0230397/11
#
# Helen Usd of Us ana/or
#
# eal
# File found: 34
#
# Extracted Text:
# value SIZES
# Cera
#
# DEVELOPED WITH DERMATOLOGISTS
#
# Renewing
# SA Cleanser
#
# For Normal Skin
# Gently cleanses & exfoliates while
# softening & smoothing skin
#
# Non-comedogenic, non-drying,
# non-irritating
#
# With ceramides & salicylic acid
#
# £02 (473 mt
# File found: 35
#
# Extracted Text:
# SPRING @ VALLEY.
#
# EXTRA STRENGTH
# Probiotic
#
# DIETARY SUPPLEMENT
#
# a
#
# z
# 2
#
# 2
# z
#
# =
# eI
# 2
# Fy
# =
# a
# B
# =
#
# This puts tite dans, eu crit ay dias,
# File found: 36
#
# Extracted Text:
# Supplement Facts
#
# Lactobacillus rham
# Lactobacillus plantar
#
# Bifddobs gum NI316.
# Lactobacillus acidophi
# Streptococcus thé
# Bifidobacterium breve NI312.
# Bifidob.
#
# Lacto
#
# OTHER INGREDIENTS:
# Starch, Hypromeliose, Inulin
# Maltodextrin, Magnesium
# stearate, Titanium Dioxide
# (capsule coloring agent)
#
# DISTRIBUTED BY:
# Watmart Inc..
# Me, AR 72716
# OF CANADA
#
# +Contains a minimum of
# 10 billion Colony Forming
# Units (CFUs) per capsule at
# time of consumption. if prior
# to expiration, under
# fecommended storage
# conditions
#
# SUGGESTED USE: Adults and
# Children 6 years old and over
# take one capsule daily at
# mealtime
# File found: 37
#
# Extracted Text:
# equate
#
# Petroleum Jelly
#
# = White petrolatum
# * Skin protectant
#
# NET WT 13 OZ (368g)
# File found: 38
#
# Extracted Text:
# Drug Facts Drug Facts (continued)
#
# Active ingredient Purpose | When using this product m do ni
#
# White potrolatum USP (100%) ..... Skin protectant | See a doctor if condition lasts more
# [S@S ™ temporarily protects minor: Do not use on Mm deep or puncture
# Mis « scrapes « Burne mi temporal protects, | M animal bites ml Serious burns
#
# ‘and helps relieve chapped or cracked skin and [Keep out of child
#
# fing a heips protect tom the drying offects of | h"etanomed, get medical tip or contac
#
# sin and cold weather, Poison Control Genter right away
# farnings ii iT
#
# pangs eee pe | Directions appiy as needed
#
# Sstisfaction guaranteed - For 530627
#
# — am
#
# Disses call 1-888-287-1915.
# 3
#
# TooriosssD.
# File found: 39
# Extracted Text:
# PanOxyl
#
# ACNE FOAMING WAS!
#
# 10% Benzoyl Peroxide
# Maximum Strength
#
# Clears Existing Acne
# and Helps Prevent N
# Breakouts from Forming
#
# Treats Acne on Fa
# and Body
#
# Maximum Strength
#
# without a Prescription
#
# Contains Benzoyl Peroxide,
# an Antibacterial Ingredien
# File found: 40
#
# Extracted Text:
# Drug Facts
#
# pmon and drys more tkely to occur you u
# Tiahe ino. ilation occur, only use one topcal act
# i imecessary sun exposure and use a sunscreen
# Bsc wr so oc, ns anc mouth a
# Sct wth haicand yo tat bed by tha pro
# pesicurion may occur, characterized by redness, buming, ilching,
# Welatios may be reduced by using the product lose freak
#
# start with 1 application
# increase to 2 or 3 times dally if needo directed 0
# dynes or pecling occurs, reduce application to once # day
#
# ing this product. If irritation or
# bah products and ask a doctor.
#
# tulfosuecinate, glycerin. pal
# ‘diol, purified
#
# Stered trademark
# fw Laboratories, |
# File found: 41
#
# Extracted Text:
# rYrour
#
# life
#
# can be
#
# full of
#
# joy and
# satisfaction.
#
# this
#
# Jt [sysnne
# no doubt
# at all.
#
# POWER
#
# POSITIVE
# THINKING
#
# NORMAN VINCENT PEALE
# File found: 42
#
# Extracted Text:
# Believe
#
# in yourself!
# Have
#
# faith
#
# in your
# abilities!
#
# With
#
# sound
# self-confidence
#
# you can
#
# succeed.
# File found: 43
#
# Extracted Text:
#
# File found: 44
#
# Extracted Text:
#
# File found: 45
#
# Extracted Text:
# Nutrition Facts
# 1 serving per container
# Serving size 1 pks. Dry (56g)|
#
# ‘Amount por sorvi
#
# Caiories 210
#
# % Dally vate
# Total Fat ia
# ‘Saturated Fat 0
# Trans Fat
# Cholesterol omg
# Sodium 590mg
# ‘Total Carbohydrate 459
# Dietary Fiber 4g 14%
#
# i
#
# il
#
# 5003
#
# Total Sugars 4g
#
# includes 0g Added Sugars 0%
# in 59
#
# ———
# Vit.D 2meg 6% * Potas.320mg 1096
# ron 12mg 65% « Galoium 250mg 25'
#
# “The % Daly Value (OV tals you row mach anit
# ‘Masering food conte to a dally et 2.000,
# lores ra bon ace
# = ——s
# File found: 46
#
# Extracted Text:
#
# File found: 47
#
# Extracted Text:
# TO: Company Name
# Address, City
# ZIP. State
#
# PRIORITY MAIL
#
# FROM: = Company Name , Address , City , ZIP , State
#
# LOT NUMBER: REF NUMBER:
#
# Item nr
#
# = AM
# File found: 48
#
# Extracted Text:
#
# File found: 49
#
# Extracted Text:
# The % Daily Value (DV) tells you how much a nutrient in a
# serving of food contributes to a daily diet. 2,000 calories a day
#
# Nutrition Facts
# Noout 255 servings per container lair ousaal evn oe
# Servi INGREDIENTS: CREAM, SKIM MILK, SUGAR, MANGO PUREE,
#
# my Size 213 cup (i 389) MANGO, CORN SYRUP, EGG YOLKS, PECTIN, ORANGE JUICE
#
# CONCENTRATE, NATURAL FLAVOR, LEMON JUICE
# CONCENTRATE.
#
# CONTAINS: MILK AND EGG INGREDIENTS.
#
# DISTRIBUTED BY: DREYER’S GRAND ICE CREAM, INC.
#
# OAKLAND, CA 94618
#
# "0 SIGNIFICANT DIFFERENCE HAS BEEN SHOWN BETWEEN MLK FROM ST
#
# TREATED AND NOW-rBST TREATED COWS.
#
# iaogen-base GY roneveee™) $F
# eff
# LE
# He
# &
#
# oM"74570'46203 2 i
# File found: 50
#
# Extracted Text:
# FBA Box 1 of 1 - 1lb
#
# SHIP FROM SHIP TO:
#
# James Bond FBA: dnest+sta012
#
# 333 Boren Ave N Amazon.com Services, Inc.
# Seattle, WA 98109 4255 Anson Blvd
#
# United States Whitestown, IN 46075-4412
#
# United States
#
# FBA (10/30/19 10:55 AM)
#
# zs
# ae
# FBAI bee
# a
# |
#
# 5JD9C5R9U000001
#
# Mixed SKUs
# KM-SSHL-KJON
# Qty 1
#
# PLEASE LEAVE THIS LABEL UNCOVERED
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-597e2cb48de9> in <module>
#     112 sequences = df_encoded.apply(lambda x: list(x), axis=1)
#     113 max_length = max(df_encoded.apply(len))
# --> 114 padded_sequences = pad_sequences.reshape(padded_sequences.shape[0], padded_sequences.shape[1])
#     115
#     116
#
# AttributeError: 'function' object has no attribute 'reshape'

# %%
import os
import re
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import pytesseract
from PIL import Image
import string
from nltk.corpus import stopwords
import pandas as pd
from tabulate import tabulate
import easyocr
from concurrent.futures import ThreadPoolExecutor

# %%
#Transformer library installed and did not go through, prob deapricated, easyocr the upgraded version.

# %%
# Set up Tesseract OCR
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Path to the folder containing PNG images
folder_path = "C:/Users/hseit/Desktop/SummerMCREU/images/"
amount = 0
extracted_data = []

# %%
# Keywords for feature detection
keywords = {
    "product_title": ["product name", "name", "product"],
    "directions": ["directions", "usage", "how to use"],
    "supplements_or_elements": ["supplements", "elements", "ingredients"],
    "warnings": ["warnings", "cautions", "precautions"]
}

# Load the OCR reader with the Transformer-based model
reader = easyocr.Reader(['en'])
print()

# Iterate over the PNG images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        amount += 1
        print("File found: " + str(amount))
        # Load the label image
        image_path = os.path.join(folder_path, filename)
        image = cv2.imread(image_path)
        print()

         # Preprocess the image
        resized_image = cv2.resize(image, (800, 600))  # Resize the image
        normalized_image = cv2.normalize(resized_image, None, 0, 255, cv2.NORM_MINMAX)  # Normalize pixel values
        denoised_image = cv2.fastNlMeansDenoisingColored(normalized_image, None, 10, 10, 7, 21)  # Denoise the image
        gray = cv2.cvtColor(denoised_image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale

        # Perform text detection
        contours, _ = cv2.findContours(gray.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        text_regions = []
        for contour in contours:
            x, y, w, h = cv2.boundingRect(contour)
            if w > 10 and h > 10:  # Filter out small contours
                text_regions.append((x, y, w, h))

        # Find the contour with maximum area
        max_contour = max(text_regions, key=lambda r: r[2] * r[3])
        x, y, w, h = max_contour

        # Crop the image using the contour coordinates
        cropped_image = gray[y:y+h, x:x+w]

        # Perform text recognition on the cropped image using the OCR reader
        extracted_text = reader.readtext(cropped_image)

        # Extract the recognized text from the OCR results
        generated_text = " ".join([text[1] for text in extracted_text])

        # Match keywords to determine the feature type
        extracted_dict = {}
        for feature, feature_keywords in keywords.items():
            for keyword in feature_keywords:
                if keyword.lower() in generated_text.lower():
                    extracted_dict[feature] = generated_text
                    break

        # Store the extracted data
        data = {
            "image_path": image_path,
            "product_title": extracted_dict.get("product_title", ""),
            "directions": extracted_dict.get("directions", ""),
            "supplements_or_elements": extracted_dict.get("supplements_or_elements", ""),
            "warnings": extracted_dict.get("warnings", "")
        }
        extracted_data.append(data)

        # Display the results
        for region in text_regions:
            x, y, w, h = region
            cv2.rectangle(resized_image, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Print extracted text
        print("Extracted Text:")
        print(generated_text)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# File found: 34
#
# Extracted Text:
# essential Waitrose british beef diced steak SA sooge
# File found: 35
#
# Extracted Text:
# FBA Box 1 of 1 Ib SHIP FROM SHIP To James Bond FBA dnest-sta012 333 Boren Ave N Amazon com Services Inc Seattle WA 98109 4255 Anson Blvd United States Whitestown IN 46075-4412 United States FBA (10p0n19 1OS5 AMA FBA1SJDICSRIUOOOOO1 Mixed SKUs KM-SSHL-KJIN Qty PLEASE LEAVE THIS LABEL UNCOVERED
# File found: 36
#
# Extracted Text:
# ALUMINUM FREE Oed <Spicer PURE SPORT HICH ENDURANCE€ DEODORANT NET WT 24 0Z (68g)
# File found: 37
#
# Extracted Text:
# CONTAINS OpOR_FIGHTING "ATOMIC ROBOTS" THAT "SHOOT LASERS" 'Svith YOUR STENCH MONSTERS AND REPLACES THEM FRESH, CLEAN, MASCULINE SCENT ELVES: 48 HOUR ODOR PROTECTION DIRECTIONS: Twist Up product: Apply tO underarms only: Use daily for best results MARNINGS: DO NOT APPLY TO BROKEN SKIN: IF RASH OR IRRITATION DEVELOPS DISCONTINUE USE: USE ONLY AS DIRECTED: KEEP Out oF REACH OF CHILDREN_ DUGREDIENTS: DIPAOPYLENE GLYCOL, WATER, PROPYLENE GLYCOL SODIUM STEARATE POLOXAMINE 307,FRAGRANCE, PPG MYRISTYL EThER; TETRASODIUM EDTA VioiET 2, GREEN 6 2 QUESTIONS? ouu 677-7582 WVaw oldspice comi Distr_by Lezet&op coxeati, 0HBzo2 L0 1 @e PLAETIC M pn STIck 49 "rurNyzhdg 304 7 TNWU Pe6 Jouti
# File found: 38
#
# Extracted Text:
# Drug Facts Active Ingredient Purpose (per tablet) Carbonate USP toOmg Antacid Usesrelieves hearthurn acid indlgestian sour slomacl UDSCi stomach asxuGiatedwuith these sYtrpLoms Warnings Ask doctor or pharmacist belore use It you are presently taking prescriplion drug_ Anlacids may interact wlth cerlain pquscription drugs Wlhen Ing this rodlc do nollake Tore Tnan tablets 24 hours prennant do nottake more than tablets nours do not UsC Lfic Maximum dosadc Tor morc [han 2 wucks except under the udvicuaud supelvisionol uuclor out Onreach chMdren Directions adults and children 12 years Of age and over: chow Lablets #5 symntoms asdirected by dmgtor du not taku (or svmptums JccthZt persisefoemore Hiun weeks uniass aQVIsCd DY dacior Other information bach tablet contalng: elemental calcium 40Orng_ odiumi store beluw 30 (36 Tnactive Ingredients adinic acid Lu stanch FD&C bluue ake FD&C red #40 laku. FD&C yellow #5 (lurtrazinc) lake FD&c yellow #6 lake Tiavons [tircral oil, sodium polyplusphalv_ Bucrose talc Salely Boalco not u88 printed Innot tions? Bn bcncath Miesing uues -800-807-7535 Wncekdavs WVIV' tUrng.cOITI GSk CH 07054 diuto 035 93XB Wvarrun 92014 GK FM?t EXP MAY/2025 Colcium Keep 2mq
# File found: 39
#
# Extracted Text:
# To IN SECONDSZ NDC 0135-0118-03 LCIUM CARBONATE TUMS ANTACID Assered Froir Uktbai0oo 72s357288 caagvc 103882* WorK  GOES
# File found: 40
#
# Extracted Text:
# NJATRQL Melatonin QOn8 SLEEP Fall Asleep Fastert Stay Asleep Longert 100% Drug-Free 90 GUMMIES DIETARY SUPPLEMENT Unth othei STRAWBERRY natural Mlavors
# File found: 41
#
# Extracted Text:
# DIRECTIONS: Take 2 gummies Manufactured in # lacility that 20-30 minutes before bedtime- processes products containing Milk, Eggs_ Tree Nuls, Peanuts supplement Factz Wheat; and Soybcans Serving Size: 2 Gummios Servings Per Containen 45 STORE IN A COOL DRY PLACE KEEP OUT OF REACH OF CHILDREN: amount Per Eening PDY Calories Those statements have not Total Iponydrate boan ovaluated by the Food [0I Sugars and Drug Administration: Includes 39 Added Suqars This productis not intendod Sodium to diagnose, breat cure Or AMe Bronin prevent any disease- Percent Daily Values are based on - O00 calorie diet WARNING: This product is not Dailx (QVnot establlshed intended to treat insomnia Do not OTHER INGREDIENTS: Organic Tapioca take while operating machinery or Syrup; Organic Cane Sugar; Water; driving vehicle_ Consult Contains 2 percent or less 0f (Citric Acid, physician before using this Coconut Oil; Carnauba Wax_ Fruit and product if you are taking Vegetable JJuice (for colory; Natural medication, have any medical Flavors, Pectin; Sodium Citrate)- condition; aro pregnant or for NATROL LLC, lactating; havo an autoimmune Manufactured conditlon dopressive disorder; 0r Chatsworth CA 91311_ USA arc between the ages uf 12-17 1-800-2-NATROL (800-262-8765) Not for use by childron under the w-natrol-com age of 12 TCa 49l Value
# File found: 42
#
# Extracted Text:
# Cerave DEVELOPED WITH DERMATOLoGISTS Daily Moisturizing Lotion For Normal to Dry Skin Moisturizes & helps restore the protective skin barrier With essential ceramides & hyaluronic acid LIGHTWEIGHT AlE E: n11a 12 FL OZ (355 ml) FI Afeet ze
# File found: 43
#
# Extracted Text:
# CeraVe Daily Moisturizing Lotion Developed with dermatelogists;Its unlque formula with essentlal eramides moisturizes and helps rcetore the protective skin barrier MVE" Delivory Lightweight & Technology 0il Froe Controledrclc? -cumcdogenic all day hydraliun UOM cloq Aure Hy3turenlc Acic Fragrance Froe Atain avuid (raoranet naturalmolxture irritation Gentlc skin Allergy AChed Non comedoocnic Dircctions: APply Liberally as otten as needed_ Ocas directed by phyaician Avoid direct conlact with eyes- Ii conlac occurs rinse thoroughly with Water 2021504v0 INGREDIENTS AOuAAWATERIEAI GLYCERIN: 8237 ACE8ABRIC POtsS "858386 P6874RE Aaye SS4STE 8E4488885R; CERAMIDEAP; SEE45482286n24 Eap CARBOMED DIMETHICONE. CETEARETH-20_ MFTHOSULFATE METHYL 34828282583434 LAUROYL LACTYLATC CHO@ESTEROL EDIA DIPOTASSium PHOSPHATE_ FRO VEPARABEN HYDROLYZEG HYALURONiC ACID PHYTOSPHINGOSINE.XANTHAN GUM POLYSORBATE20_ POLYGLYCERYL-3 DIISOSTEARATE (CODE FLL. D215763/2] SCv8rlt$_ 10001 6 reoisteredtracurnerk Co5R2357948n88or Hente ccrovo-com comnmentez 768-2*18 S04Qu 3612621748253 etd-
# File found: 44
#
# Extracted Text:
# BAUSCH LOMB A D V A N C E Eye Relief_ Dry Eye LUBRICANT EYE DAOPS Fast relief from eyes Replenishes tears Rejuvenates eyes GtE il E " ' | | 0z (15 ml dry
# File found: 45
#
# Extracted Text:
# Drug Facts Active ingredients Purpose Glycerin (0.39) Lubricant Propylene glycol (1.0%)_ Lubricant Uses temporary relief of burning and irritation due to dryness of the eye provents further irritation Warnings For exterqal us0 only Do not use if solution changes color or becomes cloudy using this product do not touch tip of container to ary surtace to avoid cortamination remove contact lenses bcfore using replace cap after use Stop use and ask doctor If you expericnce eye pain_ changes in vision; continued redness Or irritation of the eye condition worsens or persists for more than 72 hours Keep out af reach of children_ If swallowcd_ gentee medical help or contact Poison Control right away Directions instill 1 or 2 drops in thc affected eye(s) as nccdad WWhen
# File found: 46
#
# Extracted Text:
# FARMER Pvp Sproy GRAISINS BRAND DRIED CRAN- BERRIES No ARTifiCiAL FLAVORS Or PRESERVATIVES THE ORIGINAL SWEETENED DRIED ) CRANDERRIES = NET WT 48 0Z (1.36 kg) Dcean For: SALADS, BAKING: RECiPEsy
# File found: 47
#
# Extracted Text:
# Nutrition Fac Wenderful Abins giee 725047312 About Eup" Wieh Ritheshexle PISTACHIOS (289 without shells) WVith just pinch of Bal mount Zerviny servingaLightly Salted each calorier 160 Pistachios 6s Jow-sodiun; Paly Jlus perfectly seasoned, tasty 17% The delicious Toasted Total Fa 139 comes through in every saturated Fat 159 e22 crack piztars> Trans Fat_09 You open; Lightly Salted Polyunsa [uratea Fat359 Wonderful Pistachios ae Jou MongunsaturatedFat (9 perfect snacking salt ernatice chelegterel Omg 0% WonderfulPistachios com Sodlun 65m9 3% Scientific evidence Totur Zarbehyaae 89 3% but does nor aoees 119 prove that Dietany Fiber39 Krty eating 1.5 ounces per day Tota Sugars 29 of most nuts such includes Og_Added Sugars oe pistachios, a3 part of a diet Iovm Pretein 129 saturated fat and cholesterol may reduce the risk of heart disease See Vitamin omcg nutrition information for fat content alcium B0mg 0 2021 Wonderful Pistadics € Aaeuc mg All Rights Reserved WONDERTUL Fn ~Smd 280m9_ PROTEIN the accompanying kec 3 19mg 1582 trade dress are trademarks Tan 2082 Pistachios & Almonds Kus 1080 eslm 89 g83 ~pper 0 4082 132 #ong Dv) to" Fre? MUcT nuinene Gluten Jall Oiai 2000 F On aovice Sea salt- 50% less sodium thanso59 by Wonderful Pistachios; Lightly Salted D CA 93249. while Roasted & Comt Product of USA Pe" Wenderful e Tato 69 010 W LLC 3img nosp i30mg zomg 3em9 Menganeec En 3ema TccD 02s Coc Roasted & Stnedttet Vgredients Pistachios Olen Huced 3s Gontattng Aains 5 ills; Salted Bat
# File found: 48
# Extracted Text:
# Wonderful_ Nutritor per 533 PISTACHIOS Aebvins Sige 7204882 cup with pinch of salt  each Segingihout shells) WVith just (289 servingof Lightly Salted Wonderful 7idi nnn  160 Pistachios 1s Ea e Bodium 83ieiss perfectly seasoned; tasty snack_ Daly Valuc The delicious roasted 34 17% comes through in every pistachio Total Faed Far159 32 crack open Lightly Salted 09 Nongerfui Pistachios are your Ted Fat 3 59 perfect snacking salt-ernative aed en 02 WonderfulPistachios.com cholesterel Omg Sodiun EomO 3% Scientific evidence suggests Total crbehydrante 89 3% but does not prove that ` FiDE 39 Te eating ounces per day 34g25 29 Keactfy of most nuts, such rouoc5 0g Addeq Sugars 62 pistachios, as part of diet low Protein 69 129 saturated fat and cholesterol may reduce the risk of heart disease See Omcg nutrition information for fat content: 2021 Wonderful Pistachios & Almonds LLC AlI Rights Reserved_ WONDERFUL, PLANT PROTEIN, the accompanying logos and trade dress areatrademarks of Wonderful 20' Pistachios & Aimonds LLC or its affliates: 102 82 nese 403 15% ER Vounov Mucn nutnieni Deni ZPSIC dail G OoO Gluten-Free Donca nutriion jovicc Pistachios sea salt_ 50% less sodium than our {aondertul Pistachios Lightly Salted contains 65m10 Product+aa while Roasted ? Caon flavor Fal zoning Jmo Ig z0mg 30mg 36m9 NO 0.35ni9 CoMndulc? 03"4 Ivatlely onts Salted ' per serving Roasted  Tof sodium E 4135m0. Gontains
# File found: 49
#
# Extracted Text:
# detvlla Nutrition Facts 25 servings per container Servlng size pack (50g) (4 biscuits) Amount per aervinp Galorles 230 9 Dally ATE Hotel Fat 80 102 Saturled Fat0.50 3% Trans Fat Qg_ Bholertero 0mo 02 sodlkun 220mp 10% WDO Carhohydrte 262 432 Dletar Hber29 12 Tatal jwgars Iuc-ludcs Aoded SuGMNS Protein Vitaml OMic:o 0% Calcium oma 0% Iron Drtini 10% Potassium B0nin 02 Thlamin O.7mo 10% Ribollavin Smq 10 Nlaclu Iina 102 Vltamiu 0G Lmo 10%2 7 Dally nuen TUEritian naMca 7ot LaU 3 "a6e" 3 At 373207127735 E3 comeie 7or89480L Llc Fagt Innytn_ Cnmatane ~eaco Kuou indattt 4- E J: 120 140 1 attaa 1
# File found: 50
#
# Extracted Text:
# 3 # 3 4iO I # # # 1 2 2 L 0 J 3 83 0 3 3 8
# File found: 51
#
# Extracted Text:
# NDC 11822-3155-4 first aid antiseptic oral debriding agent HYDROGEN PEROXIDE 3% USP 32 FL OZ (1 OT) 946 mL Flo-Fzz0c LB00E507
# File found: 52
#
# Extracted Text:
# Drug Facts saetneeenepEeg MoxotoitaoG Active ingredient Purpose Hydrogen peroxide 390 - First aid antiseptic/oral debridingagent Uses aid to help prevent the risk of Infection in minor cuts, scrapes, and burns aids in the removal of phlegm, mucus other secrotions associated with Occasionai sore mouth Warnings For extema use only: Do not use in the eyes or apply over large areas of tho body lonoer Ihan one week Ask a doctor YOu have deep puncture wounds, anima bites Or_scrious bums Stop use and ask a doctor swelling; rash, fevor develops the condition persists gets wurse Rm mouth symptoms do not improvc days Inlation, pain, npuness persists worsens Keep out ofrcach Of children: Il swallowan Madica cantaci Foison Control Center (1-800-222- p2z3 Tidcallhelp or Direc For use a8 firgt aid antiseptic: cluan aniccted arca bandaned Hinst dry - apply small amounl of product on afiocted arca 1-3 tlmes Mlay De Coverrd Wuith aterllo bandago day For USO an ora debriding agunt (oral ringe): adulls and children ybars age and over: mix with an cqual amount waler swish around in tha moulh over arlected arca for at lcast Minute ad tnen spit out_ Do nnt swallow use up to times dally after muals and bedtlme direclud hv dentist or doctor children under 12 years should be suparvlsed in the USD af this product cnildron under years 0f age= consulr doclor dentist Other Want Information kecn tightly closed and in placu room tetnperaturu noL smiake nlne Hold awat Trom lace when oponing: Inactive ingredient @me water Questons Or cominents 8 Gull-877-753-3935 Monday QAM Spne EST 238@89 TABY; GPS2 HUNTERLANE 8 llw-rileaid RAPpsFAcioy rclund Yaur Guarantee; If you # nol {ota/e4  704 Azz0C LB00A104 first bbafore tions
# File found: 53
#
# Extracted Text:
# KILLS 99.9% OF GERMS THAT CAUSE BAD BREATH, PLAQUE & GINGIVITIS soocdt AnTiSEPTIC LISTERINE CooL MINT FOR A FRESHER & CLEANER MGUTH THAN BRUSHING ALONE ADA Accepted TITcrd 15L (1 Ot 1 Pt 2 7 4nton Sodtotot Il uz)
# File found: 54
#
# Extracted Text:
# PROVEN: Kills Gerns br Wiciouai %roGentact CLINICALLY LISTERINE@ Antiseptic #rice dailyK" tem Prevent & Reduce Use COOL MiNT@ Gingivitis Freshen Breath Kill Germs Between Teeth Prevent & Reduce Facts Qund Drug Purposes TuRH Active Ingredients SrFM EOUEZ  tha (p Euxnr 0 092 - Antiplaquelantigingivitis Ho cuZFcap endi Mentnol 0 0429* 06026 ThiS FORMULA Trml Uuc Uses 072lns prevent and reduce Plaque gingivitis IS NOT SOLD TO Wamings ANY RETAILER AS Donot Lee_ chiluren under 12 years olag0 _ A StorE BRAND: 5mptomg persist Wew Symptomg appear Or conditions worsen after regular put of reach ot chlldren: more than used for rinsing accldentally swallowed get medical nclp Thc LISTERINE  Lottia D COC Roienn Conto  Centcr Eice desiqu Nrjistarea trudemulk Directions rinse full strength for 30 seconds with 20 mL (2/3 fluid ounce teaspoonfuls) Jonnson Johnson nuuonott conolswallnv Oterintonmation this rinse not intended t0 replace brushing or tlossing Bnn at roOM Eereyde Duoweanet Mai Llquq Inis producL lls antiseptic properties are noL affected  Inactve ingrodients Water Ncohol (21.69) . Sorbitol , Poloxamer 407 , Benzoic Acid, Sudlum TLSUIM Benzoate GiCLn Questons? calltoil-free 888-222-0182 0r 215-273-8755 (collecl) uanoumd BOTTLE Helps preventand ADA reduce plaque Aeeeptod Helps prevent and reduce gingivitis Diatnib jOHNSON CONsumen NWG; Isteria com skllian_ GguO JCI 202 Hannn nginalearanmn Plaquc Jght Flatol PLasme 497 005 3zosa daal 42
# File found: 55
#
# Extracted Text:
# WGREDiEHTS: DISTILLEDaNATER Bentonvile; ARIe DISTRIBUTED BY: Walmart InG; Noi STLRIE USE 45 DRECTED EX PER BR1F5E 04520EEGesGuRoToO -TENEdeLeTortto EnnsGARooxL SouRNG DREOTILED  R GaLTomNfor AtioN FOR ISTo348469880n4n Squ,Grgroonou@oou CALLI Ihis Parent s Cholce product, In iaG,hc You'I iove rcnin fhc pitduato US end wch baby) = aren t completely happy please = Teplace ! it or retund your morer: lot to us,s0 If_ Ik Disted tctaicptaousncans 2e -877-307-2192 Ced #S4 @ WVate ELSuc JUO S 1330 TGAL (3-78 Parents choice guantee You&5 NYSHD
# File found: 56
#
# Extracted Text:
# ACQUA DI GIO GIORGIO ARMANI ABSOLU TtTCNOTTTCnD
# File found: 57
#
# Extracted Text:
# GOLD STANDARD SWHEY SOR MUSCLE proTEWEN WHEY 245 5.56 Dima PROTEIN BCAAs BANNED MaiFArum8sEr , 208POrOS ENUURANCE tested_ 4335" MALT ARtificially FLAVORED PROTEIN POWDER DRINK MIX NETWT 5LB (2.27 KG) Gocc UPPIAMEH @o Nnu Arnren TFDUI SUPPORT RECOVERY CHOCOLATE SerVGS tnetn
# File found: 58
#
# Extracted Text:
# 44We4 Zacts 73 servings per container Serving size 31g (About Anlount per servlng Calories 120 Ab0u5, scdop %n Daily_ Valuet Total Fat 1.59 Saturatcu Fat Cholosterol Sadium Total Carbohydrato 30 For best results; 'ix up TC: Sugars YOU work Dut; Dr Iiave Veu Protoin 245 dianan-e 4945 hign-prctein dipt C crn Irin 0,8mg GCLd STANDARD 1ugX WheY", I5 0e37 PolzssiUM mixability an: surericr drinkabily IJt %unz 0im570 Uls, Jmin jnjwjsinjysRd Urcy mjh Check out OPTIMUMNUTRITIOM CgM; 4caadA BrCntuid "ttnz WJcacnas trainirig tips INGredients; Blend Sloregter Dor 'iegtraou cynsoh Bulete Wtav rotuin rrotoin requiremen eKn Cemonatn concentrato  Hydrolyzed nature Coraa (Procossed protet Lple en 3 thrulighovt furtificia with Alkali) Daane riavdr Drojeim und{or Creamer (Suntlower Dil; Tnaue Dccurrinl Amind ) 1d9 Food Starch Dipotarsium Fhosphato, Tocophurcisn Iohem takrn Ute rime %It^ rAgulz" Sucralose Milk AND S0y: OR optueagturrition, Inc 76 65 1500 Lacey Roau; Sulte Lzo0 Grove 60515 Bon) 705-5226 SOLD NOT MANUFACTURED TTtny Scooph GRAMS 6-8 FL 0Z da Fa5e0oe protein VLLn rcwo Jerleote 25n1 097g SShate 318 lancen; 3ou 2209 18 7" Va Ftote n (uiav Frutein Prote IOOCE Sulaeitr; Sunilownr Lic hl Moctiad Feso Iric Ician ALRU Polais Mau contaiS:  dowinet eontelgts , VoLuMe; settling Will tNc Us4 Occur:
# File found: 59
#
# Extracted Text:
# Mbuv Scoopl 31 GRAMS 6-8 FL Oz 30 SECONDS aqut colm WaTER , 120 MILK OR stibLSwoKe PROTEIN UIHER DISSOLYCOUNTIL Daily Value" PoyMnfr BEVERAGE Far best results, mix Up your shake 30-60 minutes after ycu work out; Cr have it as an anytime snack in yaur palanced, high-protein diet GOLD STANDARD 10O% WHEY " is designed fer raximum mixability and superior urinkability; Check Out OPTIMUMNUTRITION.COM for recipes &d tips: Sungjalnd hebithi Mcyricvr Boute Lunfum Enrushprorsin protelm requirerpnts cambinatlon af hirh prutein {jomz 8r" aupplatcn s tnroughuut Datt palaricer diet anc Oceurriny Amine Jcics taket "itateouar Tesslanel Tinijy: Ox TopE conL Wry PLACL E scdof INCLUVEV ourine ShPPi Suitu 1200 605. Uthe Us 43027 022 Facts Ae training " Aocily Hoet Jun meflrjmv Toik9o mfen nce optwenftnaer Ron ,= acet Oo dbt Tm 8226 Mnutactuald Sn
# File found: 60
# Extracted Text:
# laws Classic Rutalo Cnips Net 10 0Z 297.6 @i Size Famiv
# File found: 61
#
# Extracted Text:
# BURGER PLANT-BASFD 20G. No pe8] BEYOND MEAT BEYOND Pat TIEc GLUIEN
# File found: 62
#
# Extracted Text:
# Wutronacs 1 serving per container 9 1 Serving size Pkg. Dry(569) 3 2 8 Amount Galories Per 210 6 83 % Daily Value 8 Total Fat 1g 083 Saanserad 8909 0% Cholesterol Omg Sodium 590mg 25% Total Carbohydrate 459 15% Dietary Fiber 4g 14% 3 Total Sugars 4g 3 4 Includes Og Added Sugars 0% 3 Proteln 59 vil; 2mcg 6% Potas. 320mg 10% 3 Iron 65% Caicin 250rng 25% DilyViluo  Icllg yau m4#much nulient 07 #GctIr) Gocdmnnaner daily diet: 2,0C0 calonesa&7 Fnr nerarl nutritlon adjce. 1 1 0 ! 2 2 I 3 8 1 8 2 1 8 0 8 1 1 72mg
# File found: 63
#
# Extracted Text:
# To: Company Name P Address, City ZIP. State PRIORITY MAIL FROM: Company Name Address , City ZIP State LOT NUMBER: REF NUMBER: SHIP DATE WEIGHT: HANDLE Item nr 1 WTH FRAGLE CARE Delivervy instruction:
# File found: 64
#
# Extracted Text:
# prime
# File found: 65
#
# Extracted Text:
# Nutrition Facts  The % Daily Value (DV) tells you how much a nutrient in a senving of food contributes t0 daily diet: 2,000 calories day About 2.5 servings per container used for general nutrition advice: INGREDIENTS: CREAM,SKIM MILK SUGAR; MANGO PUREE (Serving Size 213 cup (138g) MANGO, CORN SYRUP EGG YOLKS, PECTIN; ORANGE JUICE CONCENTRATE, NATURAL FLAVOR LEMON JUICE Per serving Per Container | CONCENTRATE CONTAINS: MILK AND EGG INGREDIENTS: Calories | 33/ 870/ DISTRIBUTED BY: DREYER'S GRAND ICE CREAM; INC: OAKLAND; CA 94618 %3 DV" % DV" "Ho SGMACAMI DIFFERENCE HAS BEEM SHOWM BETHEEN WILK FROM teST TotalFat Wg 77 459 5587 TREATED AND Non-(eST TREATED CoXS FaturatedFat Wg 557 299 7457 Irans Fat 059 150 7mg27 79dmg 633 Sodium 65mg MT EZ 409 0 M 0 Haagen-Dozs Honey Bees" <lg 29 Toaal 39 969 bcl Aooed Sugars | Z9 567 0 1463 30 Prolemn 12g K L7mcg_83 I0r 360mg 258 Iron @mg Q4mg 28 W 610mg 103 144570 26203' Cholesterdl 1 } [uc2s 0 1 DMIES " Vitamin _ 1 Q6ucq J Calcium Tg Potassium Fh
# File found: 66
#
# Extracted Text:
# FBA Box 1 of 1 Ib SHIP FROM: SHIP To: James Bond FBA: dnest-sta012 333 Boren Ave N Amazon com Services Inc. Seattle, WA 98109 4255 Anson Blvd United States Whitestown, IN 46075-4412 United States FBA (10/30119 10S5 AMA FBA1SJDICSRIUOOOOO1 Mixed SKUs KM-SSHL-KJIN Qty PLEASE LEAVE THIS LABEL UNCOVERED

# %%
# Keywords for feature detection
keywords = {
    "product_title": ["product name", "name", "product"],
    "directions": ["directions", "usage", "how to use"],
    "supplements_or_elements": ["supplements", "drug facts", "ingredients"],
    "warnings": ["warnings", "cautions", "precautions"]
}

amount = 0
extracted_data = []
# Faster method for process_image algorithm using threading
def process_image(image_path):
    global amount
    amount += 1
    print("File found: " + str(amount))

    # Load the label image
    image = cv2.imread(image_path)

    # Preprocess the image
    resized_image = cv2.resize(image, (600, 600))  # Resize the image
    normalized_image = cv2.normalize(resized_image, None, 0, 255, cv2.NORM_MINMAX)  # Normalize pixel values
    denoised_image = cv2.fastNlMeansDenoisingColored(normalized_image, None, 10, 10, 7, 21)  # Denoise the image
    gray = cv2.cvtColor(denoised_image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale

    # Perform text detection
    contours, _ = cv2.findContours(gray.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    text_regions = []
    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        if w > 10 and h > 10:  # Filter out small contours
            text_regions.append((x, y, w, h))

#     if text_regions:
    # Find the contour with maximum area
    max_contour = max(text_regions, key=lambda r: r[2] * r[3])
    x, y, w, h = max_contour

    # Crop the image using the contour coordinates
    cropped_image = gray[y:y+h, x:x+w]

    # Perform text recognition on the cropped image
    extracted_text = pytesseract.image_to_string(cropped_image).strip()

    # Match keywords to determine the feature type
    extracted_dict = {}
    for feature, feature_keywords in keywords.items():
        for keyword in feature_keywords:
            if keyword.lower() in extracted_text.lower():
                extracted_dict[feature] = extracted_text
                break

    # Store the extracted data
    data = {
        "image_path": image_path,
        "extracted_text": extracted_text,
        "product_title": extracted_dict.get("product_title", ""),
        "directions": extracted_dict.get("directions", ""),
        "supplements_or_elements": extracted_dict.get("supplements_or_elements", ""),
        "warnings": extracted_dict.get("warnings", "")
    }
    extracted_data.append(data)

    # Display the results
    for region in text_regions:
        x, y, w, h = region
        cv2.rectangle(resized_image, (x, y), (x + w, y + h), (0, 255, 0), 2)

        print("Extracted Text:")
        print(extracted_text)

def folderOCR(directory_path):
    image_paths = [os.path.join(directory_path, filename) for filename in os.listdir(directory_path)
                   if filename.endswith((".jpg", ".png"))]

    with ThreadPoolExecutor() as executor:
        executor.map(process_image, image_paths)

# Run the folderOCR function
folderOCR(folder_path)
# Out:
# File found: 1
# File found: 2
# File found: 3
# File found: 4
# File found: 5
# File found: 6
# File found: 7
# File found: 8
# File found: 9
# File found: 10
# File found: 11
# File found: 12
# File found: 13
# File found: 14
# File found: 15
# File found: 16
# Extracted Text:
# FBA Box 1 of 1 - 1Ib
#
# SHIP FROM SHIP TO
#
# James Bond FBA. dnest+sta012
#
# 333 Boren Ave N Amazon.com Services, Inc.
#
# Seattle, WA 98109 4255 Anson Blvd
#
# United States Whitestown, IN 46075-4412
# United States
#
# FBA (10/30/19 10:55 AM) - 1
#
# ae
# pea
#
# FBA15JD9C5R9U000001
# Mixed SKUs pnd
# | |
#
# KM-SSHL-KJON
# Qty 1
#
# PLEASE LEAVE THIS LABEL UNCOVERED
# File found: 17
# Extracted Text:
# BAUSCH # LOMB
#
# Eye Relief.
#
# LUBRICANT EYE DROPS
#
# e Fast relief from
# dry eyes
#
# e Replenishes tears
#
# ° Rejuvenates eyes
# File found: 18
# Extracted Text:
# per container
# 4 pack (509) (4 biscuits)
#
# —_7—i
# Calories _ 230
# File found: 19
# Extracted Text:
#
# File found: 20
# Extracted Text:
# ong racks a
# Active ingredient Purpose
#
# (per tablet)
# Calcium Carbonate USP 100mg.
# Usesiaieves = nearbum
# atid malgestion = sour stomach
# + use stomach assutite wt these synploms
# Warnings
# {ask a doctor or pharmacist before use Ifyou are
# presently faking preserlion erug.Antacls mal
# “eteract with cetain preserigon rugs
# When using this product
# do mel lake mora fan tablets 24 ours
# 2 ibreanant do nottake more than s fables n 28 hours
# Seanmot use tho maximum desage or more than 2 Wook
# ‘except under tha advicu and supervision ofa doce
# Keep outot reson of children.
#
# Directions
# PMdakes and shitdron 12 year of age and over: now 23
# ets us symptoms occur ects a ductor
# «= Gt ake loraumpls iat br or more an S weeks
# tines adios By ator
#
# Other information
# eh tablet contalns: clomental calcium 400mg, sodium 2m
# Store below 301°C (86°F)
#
# Inactive Ingredients adipic wd. comstarch FDC
# 7
#
# coed TO
# foe
#
# race SIM Ure5-o7a5-65
#
# GSE CH o,oroso ME 103593XB
# eae WT EXP
#
# IAY/2025
# File found: 21
# Extracted Text:
# a
#
# CeraVe” Daily Moisturizing Lotion
#
# Developed with dermatologists, its unique formuta —
# with 3 essential ceramides ~ molsturizes and helps:
# restore the protective skin barrier
#
# MVE® Delivery Lightweight
#
# Technology. Gittres St
#
# for'aliday hyaration won'telng pores
# oe Hysturonte acta @ Fragrance Free
#
# Directions: Apply liberally as often as needed, or as
# directed by a physician. Avold direct contact with eyes. I
# Sontact occurs rinse thoroughly with water,
#
# 20215004VO1 - INGREDIENTS: AQUA/WATER/EAU, GLYCERIN,
# GAPrYLIC/CAPHIC TRIGLYCERIDE, CETCARYL ALCOHOL.
# GEnYL ALCoHOL, POTASSIUM PHOSPHATE, CERAMIDE NP,
# BERAMIDE AP, CERAMIDE EOP, CARBOMETe, CIMETHICONE,
# CETEARETH.20, BEHENTRIMONIUM METHOSULFATE,
# METHYLPARABEN, SODIUM LAUROYL LACTVLATE,
# CHOLESTEROL, DISODIUM EDTA, DIFOTASSIUM,
# PHOSPHATE, PROPYLPARABEN,
#
# EVOROLYZED HYALURONIC ACID,
# PHYTOSPHINGOSINE. XANTHAN GUM,
# POLYSORBATE 20, POLYGLYCERYL-3
# DIISOSTEARATE (CODE FILL. 0215769/2)
# File found: 22
# Extracted Text:
# NATROL
# Melatonin 10=:
#
# SLEEP
#
# @ Fall Asleep Faster*
# @ Stay Asleep Longert
# ® 100% Drug-Free
#
# 90 GUMMIES
# DIETARY SUPPLEMENT ——withauner SRAWBERRY
# File found: 23
# Extracted Text:
# ALUMINUM + FREE
#
# ,
# Old Spice-
#
# PURE SPORT |
#
# ——-HIGH ENDURANCE® ——
#
# DEODORANT
#
# NET WE
# 2.402 (689
# File found: 24
# Extracted Text:
# oo Ce
# TS ean sys)
#
# CRAISINS ¢
#
# DRIED
#
# CRAN-
# BERRIES
#
# NO ARTIFICIAL FLAVORS OR PRESERVATIVES
#
# SWEETENED ORD GRANDER
# BOL (1.36 ko) |
# File found: 25
# Extracted Text:
# Drug Facts
#
# ‘Active ingredients Purpose
# Glycerin (0.3%) Lubricant
# Pronyione aiveoi (i 0%) Lubricant,
#
# Uses
#
# = temporary roliet of burning and irritation
# due to dryness of the eye
#
# ‘m_provents further irritation
#
# Warnings
#
# For external use only
#
# Do not use
#
# i if solution changes color or
# bbocomes cloudy
#
# When using this product
#
# do not touch tip of container to any surface
# to avoid contamination
#
# fm romove contact lenses before using
#
# replace cap after use
#
# Stop use and ask a doctor if
#
# im You experience eye pain, changes in vision,
#
# ued redness or irritation of the eye
#
# ‘= condition worsens or persists for more than
# 72 hours
#
# Keep out of reach of children. if swallowed,
#
# {get medical lp or contact a Poison Control
#
# Genter right away.
#
# Directions
# ‘= instill 1 07 2 drops inthe affected
# eye(s) a5 noodod
# File found: 26
# Extracted Text:
# DIRECTIONS: Take 2 gummies Manufactured in facity that
# 20-30 minutes before bedtime, processes products containing
# Pak Eogs.Tee Nuts, Peanuts
# Supplement Facts] test ani soneas
# ing Size: 2 Gummies 4
# ore: io SSTORE IN A COOL, DRY PLACE.
# eT KEEP OUT OF REACH OF CHILDREN.
#
# ‘These statoments have not
# “otal Carbohyarata boon evaluated by the Food |
# Taal su 5 =| | and Drug Administration.
#
# Ticlodes 29 aaa Sige ‘This product is not intended
# ‘to diagnose, treat, cure or
#
# prevent any disease.
#
# WARNING: This product is nat
# intended to treat insomnia. Do not
# (OTHER INGREDIENTS: Organic Tapioca take while oporating machinary or
# Syrup, Organic Cane Sugar, Water, driving a vehicle. Consulta,
# Contains 2 percent or less of (Citric Acid, physician before using this
# Coconut Oi, CamaubaWax, Fruitand producti you ae taking
#
# Juice (for color), Natural ‘Medication, have any medical
# eee can cates, ondion, ar pregnant or
# ba lactating, have an autoimmune
# eeaserires PNT LLC. Se ‘or depressive disorder, or
# Chatsworth, USA ‘are between the ages of 12-17.
# 41-800-2-NATROL (800-262-8765) Not for use by children under the
# wwew.natrol.c age of 12
#
# el
# File found: 27
# Extracted Text:
# essential
#
# Waitrose®
#
# british beef ~
# Mw diced steak
# File found: 28
# Extracted Text:
# Cera
#
# Daily
# Moisturizing
# Lotion
#
# For Normal to Dry Skin
#
# Moisturizes & helps restore
# the protective skin barrier
#
# With 3 essential ceramides
# & hyaluronic acid
#
# 12 FL OZ (355 ml)
# File found: 29
# Extracted Text:
# CONTAINS ODOR-FIGHTING “ATOMIG ROBOTS” THAT “sHooT
# USERS" AT YOUR “STENCH MONSTERS” AND REPLACES
# THEM WITH FRESH, CLEAN, MASCULINE
#
# DRECTIONS: Twist up product. Apply to underarms only.
#
# Us daly for host results,
#
# \WANINES: DO NOT APPLY TO BROKEN SKIN, IF RASH OR IRPITATION DEVELO,
# TSOONTINUEUSE. USE ONLY AS DIRECTED.
#
# X=? OUT OF REACH OF CHILDREN,
#
# INGREDIENTS;
#
# RANGE PPG-3 MVRISTYL
# TETRASODIUM EDTA, VOLET2, GREEN 6
# uesTios? 1-s00-677-7502
# we odspica com
# Oar,
# Procten a
# OCIA Om 5200,
#
# PEG
# File found: 30
# Extracted Text:
# NDC 11822-3155-4
#
# first aid antiseptic /
# oral debriding agent
#
# HYDROGEN
# PEROXIDE
# Ls%usp_)
#
# 32 FL 02
# _., (1.01) 846 mL
# File found: 31
# Extracted Text:
# Nutrition Facts
#
# Apout 26 Servings per pack
#
# cup with si
#
# 160
#
# Serving Size About Jj
# (Zag without shells)
#
# Calories
#
# Tocra pues"
# daly eet 2,000
# nuttin acs
#
# A ced fy GPtachios, sea salt
# ‘Onderful Pistachios.
#
# Ged by Ww,
# sis,
# 4 wh Eee o219 prance
#
# Wonderful
#
# PISTACHIOs
#
# With just 2 pinch of salt. ¢,
# serving of Lightly Salted Wo. 25?
# Pistachios is a low-soq.
# Perfectly seasoned, tasty .
# The delicious roasted
# comes through in every pis
# you crack open. Lightly s~
# Wonderful Pistachios are.
# perfect snacking salt-ermnatc.,
# WonderfulPistachios.com
# Og cicwtifc evidence a
# but does not pro
# Se
# HEALTHY of most huts, such
# pistachios, as part of a diet low in
# saturated fat and cholesterol may
# reduce the risk of heart disease. See
# nutrition information
#
# © 2021 Wonderful Pista
# All Rights Reserved. WON
# PROTEIN, the accompany
# trade dress are trademarks
# Pistachios & Almonds LLC
#
# at
#
# oor es soaumienatiga
# PO eS leona aaa
# while Roasted & salieg -
# File found: 32
# Extracted Text:
# “it
#
# NT
#
# Qe
#
# s 5
# Fistachios, sea salt
#
# i Wondertul Pist:
# achio
# Big baa
#
# Wonderful
# PISTACHIOS
#
# jth just a pinch of salt, each
# seeing of Lightly Salted Wonderful
# Pistachios is a low-sodium,
# perfectly seasoned, tasty snack.
# Bhe delicious roasted flavor
# comes through in every pistachio
# you crack open. Lightly Salted
# Wonderful Pistachios are your
# perfect snacking salt-ernative
#
# WonderfulPistachios.com
# fg. Scientific evidence suggests
# Yee sees ror vows ta
# Daag leating 1.5 ounces per day
# HEALTHY OF most nuts, such as
# pistachios, as part of a diet low in
# saturated fat and cholesterol may
# reduce the risk of heart disease. See
# nutrition information for fat content.
# © 2021 Wonderful Pistachios & Almonds UC
# All Rights Reserved. WONDERFUL, PLANT
# PROTEIN, the accompanying loa0s std
# trade dress are trademarks of Wondet!
# Pistachios & Almonds LLC oF its afore
#
# noid
# 8
# 50% ess sodium than ou posta
#
# ly Salted contains Gama ots.
# While Rees contains Game ins |
# File found: 33
# Extracted Text:
#
# Extracted Text:
# jon Facts
#
# 1 serving per container
#
# Serving size 1 Pkg. Dry (56a)
#
# Gaiories 210
#
# ed By
# pra Foods, LLC
# 1d, CO 80537 USA
# s, Organi
# s Pumpki
#
# Bear
#
# Cholesterol omg
# Sodium 590mg |
# Total Carbohydrate 459 15%
# Dietary Fiber 4g
# Total Sugars 4g Z
# includes 0g Added Sugars 0%
#
# t.0 2meg 6% « Potas. 9209 10%
# ron amg 659% «Calcium 250mg 259%
# ae ate ow uch aru
# Extracted Text:
# ACQUA DI
#
# GIORGIO ARMANI
#
# ~~ ABSOLU
#
# TATOMIAICYQW
# Extracted Text:
#
# Extracted Text:
#
# Extracted Text:
# KILLS 99.9% OF GERMS
# THAT CAUSE BAD BREATH,
# PLAQUE & GINGIVITIS |
#
# ANTISEPTIC
#
# LISTERINE
# COOL MINT
#
# FOR A FRESHER &
# CLEANER MOUTH THAN
# BRUSHING ALONE
#
# yn
# = -- -
# 2
# a i SS-
# Extracted Text:
# Es
# eg 3
# a
#
# |
#
# 2 at
# ah
# er Sane
# revere
# RedState
# "ecarent)
#
# met
# ee
#
# 31 GRAM,
#
# eg Try
# Wer rt Btn
# aac me
#
# GOLD STHNARG Loe
# inet
# Extracted Text:
# S4
#
# 31 GRAI 30 SEcoNps
# ‘ar Thou
# tire asses
# ret
#
# For bast results, mx up your shake 30-60 nines at
# you workout, ch have it as en anytime sneck in aur
# bela-cee, Foh-pretein cit.
#
# GOLO STANDARD 100% WHEY" is cesioned fr mes
# aadilty ene suparordringabily,
#
# Nyc kn  de
#
# en en
# ean
#
# STORE Wa 20. eI
#
# Haney
#
# Stn 2
# ane?
# Extracted Text:
#
# Extracted Text:
#
# Extracted Text:
# Kil
# INE® Antiseptic tw oo
# itis ™ Freshen Breath Boao
#
# ‘Reduce Gingivi
#
# edluce Plaque
#
# va Aatplaque/antgingitis
#
# Vis iexrontanieme Same Gros
#
# Weaning
# Tena osn under 12ers of age
# ‘scr ons pert ne symploms appear or Goniions worsen ater regu us
#
# ech ot ln rohan se fo insing been salon, get dial
# ‘Som lomoniee nana). E a
#
# nS = etal seth th 20 ie ld une or i)
# Snug 9D sezns A mad reo eset)
#
# THIS FORMULA
# IS NOT SOLD TO
# ANY RETAILER AS
# A STORE BRAND.
#
# “Te USTERNED te
# Gear eases
# ‘radeart
#
# her information
# Oi iniomation__ ts irses nt rene io opts brushing o Tosa = soe aoa
# ase yh ay Sets pa Ts anee papers wee ee.
#
# active ing
# {icine ingredients” ver cone 1.6%), Soro, okramer 407, Bae Aca, Somme
# ssa Fino! oes OL Pra A a
#
# SONS? san rat 2 2S 67 GD
#
# ne oa
#
# ‘Helos prevent and
# reduce plane
#
# =
# ‘+ Helps prevent and
# veers
# Se tereaeae ta
# 5
#
# ‘ww
# Extracted Text:
# Drug Facts
#
# ‘Active ingredient Purpose
# Ivan poet Ft al ante et Pose
#
# Uses wm irs ald to Felp prevent tho risk of nection In minor
# uf, scrapes, and burns.
#
# ‘218 inthe rmpoval of phlegm, mucus, or other secretions
# sssoraled with occasional soe mouth
#
# Warnin
# Forever se ony
# DDonot use min the Ses or apply over large areas of Wo oy
# ‘monger than on week
# ‘ska doctor before use i you have
# ‘cep puncture wounds, animal bes or serious bums
# Stop use and-ask a doctor _m sweling ras, orfvar GeveapS
# 1 te condition persists or gets worse
#
# sof mouth symptoms do nol improve in7 days
#
# Initon pain, a redness persists or worsens
# Keep out of reach of children. evallowod get meal Tap
# ontact a Polson Cool Cente (1-800-222-1820) igh aay
#
# Directions For use as 3 frst ald antiseptic
# clean affected aroa mi bansged let at
# apply small amount of product on socted arca 1-$ mes a day
# ‘may be covered vit a tel bandage,
# For use as an oral debncing agent (oral rinse:
# ‘adults and chilaren 2 years of age and over:
# ‘noch an quel amount of water
# swe around inthe mouth over affected area for at east 1
# ‘minute and hen stot Do net sai
# ‘une up ind times daly ater meals and af bedtime ores
# oii esr oo
# ‘children under 12 years should be supervised in the usa of his
# roduc i *
# children under 2
#
# ‘Questions or comments?
#
# Lal 4-877-753-3685 Manny iy GAM-SPM EST
# DISTRIBUTED BY: RITE rib 70 HUNTER LANE?
# Gir HLT PATOL Guta
# SaTEracmON cungnaret x pores seaaeor
# Extracted Text:
# EeWHEY
#
# rs ————
# ae FOR MUSCL| |
# ee 6
# ‘COVERY
#
# CHOCOLATE MALT =
# SEIENEOWne
#
# 7asene
# WT 27 KG)
# SLBC.
# Da a
# Extracted Text:
# 10: Company Name
# Pp Address, City
# ZIP. State
# PRIORITY MAIL
#
# FROM Company Name, Address, City, ZIP, State
# Extracted Text:
# FBA Box 1 of 1 - 1Ib
#
# SHIP FROM: SHIP TO:
#
# James Bond FBA: dnest+sta012
#
# 333 Boren Ave N Amazon.com Services, Inc.
#
# Seattle, WA 98109 4255 Anson Blvd
#
# United States Whitestown, IN 46075-4412
# United States
#
# FBA (10/30/19 10:55 AM) - 1
#
# ae
# re
#
# FBA15JD9C5R9U000001
# Mixed SKUs pom
# | |
#
# KM-SSHL-KJON
# Qty 1
#
# PLEASE LEAVE THIS LABEL UNCOVERED
# Extracted Text:
# Nutrition Facts
# About 25 servings per container
# Serving Size 2/3 cup (138g)
#
# isis
#
# 23 |
#
# =|
#
# EW sl
#
# [alF
# Slo
#
# za
#
# 330 870
#
# Per Container
#
# The % Daly Valu (0 tls you how much nuttin a
# serving of fod conus to a daly cet. 2000 calor ada
# {sued for general nutiton ave.
#
# INGREDIENTS: CREAM, SKIM MILK, SUGAR, MANGO PUREE,
# MANGO, CORN SYRUP, EGG YOLKS, PECTIN, RANGE JUICE
# CONCENTRATE NATURAL FLAVOR, LEMON JUICE
# CCONCENTRAT
#
# CONTAINS: LC NOEs MEREDET
#
# DISTRIBUTED BY: DREYER GRAND ICE CREAM, INC.
#
# i i
#
# git
#
# ZEN UNTIL SER
# VER
# ada
#
# KEEP FRO7
#
# 203° 2

# %%
# Create a DataFrame from the extracted data
df = pd.DataFrame(extracted_data)

# Define a function to truncate long strings
def truncate_string(text, max_length=30):
    if len(text) > max_length:
        return text[:max_length] + '...'
    return text

# Apply string truncation to the DataFrame
df = df.applymap(truncate_string)

# Display the DataFrame in table format
print("\nExtracted Data:")
print(df.to_string(index=False))
# Out:
# Extracted Data:
#                        image_path                             extracted_text                       product_title                          directions             supplements_or_elements                            warnings
# C:/Users/hseit/Desktop/SummerM...        FBA Box 1 of 1 - 1Ib\n\nSHIP FRO...
# C:/Users/hseit/Desktop/SummerM...      BAUSCH # LOMB\n\nEye Relief.\n\nLU...
# C:/Users/hseit/Desktop/SummerM...         per container\n4 pack (509) (4 ...
# C:/Users/hseit/Desktop/SummerM...
# C:/Users/hseit/Desktop/SummerM...         ong racks a\nActive ingredient ...  ong racks a\nActive ingredient ...  ong racks a\nActive ingredient ...  ong racks a\nActive ingredient ...  ong racks a\nActive ingredient ...
# C:/Users/hseit/Desktop/SummerM...        a\n\nCeraVe” Daily Moisturizing ...                                     a\n\nCeraVe” Daily Moisturizing ... a\n\nCeraVe” Daily Moisturizing ...
# C:/Users/hseit/Desktop/SummerM...     NATROL\nMelatonin 10=:\n\nSLEEP\n\n...
# C:/Users/hseit/Desktop/SummerM...      ALUMINUM + FREE\n\n,\nOld Spice-\n...
# C:/Users/hseit/Desktop/SummerM...      oo Ce\nTS ean sys)\n\nCRAISINS ¢\n...
# C:/Users/hseit/Desktop/SummerM...        Drug Facts\n\n‘Active ingredient... Drug Facts\n\n‘Active ingredient... Drug Facts\n\n‘Active ingredient... Drug Facts\n\n‘Active ingredient... Drug Facts\n\n‘Active ingredient...
# C:/Users/hseit/Desktop/SummerM...          DIRECTIONS: Take 2 gummies Man...   DIRECTIONS: Take 2 gummies Man...   DIRECTIONS: Take 2 gummies Man...   DIRECTIONS: Take 2 gummies Man...
# C:/Users/hseit/Desktop/SummerM...      essential\n\nWaitrose®\n\nbritish ...
# C:/Users/hseit/Desktop/SummerM...      Cera\n\nDaily\nMoisturizing\nLotio...
# C:/Users/hseit/Desktop/SummerM...          CONTAINS ODOR-FIGHTING “ATOMIG...   CONTAINS ODOR-FIGHTING “ATOMIG...                                       CONTAINS ODOR-FIGHTING “ATOMIG...
# C:/Users/hseit/Desktop/SummerM...        NDC 11822-3155-4\n\nfirst aid an...
# C:/Users/hseit/Desktop/SummerM...        Nutrition Facts\n\nApout 26 Serv...
# C:/Users/hseit/Desktop/SummerM...   “it\n\nNT\n\nQe\n\ns 5\nFistachios, s...
# C:/Users/hseit/Desktop/SummerM...
# C:/Users/hseit/Desktop/SummerM...        jon Facts\n\n1 serving per conta...
# C:/Users/hseit/Desktop/SummerM...      ACQUA DI\n\nGIORGIO ARMANI\n\n~~ A...
# C:/Users/hseit/Desktop/SummerM...
# C:/Users/hseit/Desktop/SummerM...
# C:/Users/hseit/Desktop/SummerM...         KILLS 99.9% OF GERMS\nTHAT CAUS...
# C:/Users/hseit/Desktop/SummerM... Es\neg 3\na\n\n|\n\n2 at\nah\ner Sane\n...
# C:/Users/hseit/Desktop/SummerM...       S4\n\n31 GRAI 30 SEcoNps\n‘ar Tho...
# C:/Users/hseit/Desktop/SummerM...
# C:/Users/hseit/Desktop/SummerM...
# C:/Users/hseit/Desktop/SummerM...        Kil\nINE® Antiseptic tw oo\nitis...                                                                         Kil\nINE® Antiseptic tw oo\nitis...
# C:/Users/hseit/Desktop/SummerM...        Drug Facts\n\n‘Active ingredient... Drug Facts\n\n‘Active ingredient... Drug Facts\n\n‘Active ingredient... Drug Facts\n\n‘Active ingredient...
# C:/Users/hseit/Desktop/SummerM...       EeWHEY\n\nrs ————\nae FOR MUSCL| ...
# C:/Users/hseit/Desktop/SummerM...         10: Company Name\nPp Address, C...  10: Company Name\nPp Address, C...
# C:/Users/hseit/Desktop/SummerM...        FBA Box 1 of 1 - 1Ib\n\nSHIP FRO...
# C:/Users/hseit/Desktop/SummerM...         Nutrition Facts\nAbout 25 servi...                                                                          Nutrition Facts\nAbout 25 servi...
